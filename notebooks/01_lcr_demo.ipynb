# %% [markdown]
# # OSSF demo
#
# In this notebook, we will demonstrate how **Legend** and **Morphir** models can be interpreted on **databricks** with minimum development overhead. We will be sourcing information with **Legend** and feed the resulting dataframe into a **Morphir** calculation.

# %% [markdown]
# Although we could directly query the underlying tables through the spark SQL API and its multiple joins and transformations (see below), we can benefit from the model created through the **Legend** framework and access its logical representation (mapping to a legend entity).

# %%
# %sql
SELECT
  a.`id`,
  a.`currency`,
  a.`reporting_entity`,
  a.`product`,
  a.`sub_product`,
  a.`business_line`,
  m.`maturity_date`,
  m.`purchase_date`
FROM inflows.assets a
JOIN inflows.assets_maturity m
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>currency</th><th>reporting_entity</th><th>product</th><th>sub_product</th><th>business_line</th><th>maturity_date</th><th>purchase_date</th></tr></thead><tbody><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-15</td><td>2022-12-01</td></tr><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-26</td><td>2022-12-04</td></tr><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-23</td><td>2022-12-04</td></tr><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-22</td><td>2022-12-04</td></tr><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-01</td><td>2022-12-01</td></tr><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-23</td><td>2022-12-01</td></tr><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-04</td><td>2022-12-04</td></tr><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-05</td><td>2022-12-01</td></tr><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-30</td><td>2022-12-01</td></tr><tr><td>750000</td><td>GBP</td><td>entity_1</td><td>EncumberedAssets</td><td>Currency and Coin</td><td>business_1</td><td>2022-12-26</td><td>2022-12-04</td></tr></tbody></table></div>

# %% [markdown]
# ## LEGEND

# %% [markdown]
# <img src='https://raw.githubusercontent.com/aamend/ossf_db_ms_gs/main/images/wf_1.png' width=800/>

# %% [markdown]
# ## LEGEND ON DELTA
# With our **Legend** model packaged as JAR and included as a cluster dependency, we can easily access each of its underlying entities, create tables programmatically or execute queries according to legend specifications. We show below how to load our model and access a given entity (a logical model mapped to a physical table)

# %% [markdown]
# <img src='https://raw.githubusercontent.com/aamend/ossf_db_ms_gs/main/images/wf_2.png' width=800/>

# %%
# %scala
import org.finos.legend.spark.LegendClasspathLoader
val legend = LegendClasspathLoader.loadResources()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import org.finos.legend.spark.LegendClasspathLoader
# legend: org.finos.legend.spark.Legend = org.finos.legend.spark.Legend@22c968ac
# </div>

# %%
# %scala
display(legend.getEntityNames.toList.toDF("legendEntity"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>legendEntity</th></tr></thead><tbody><tr><td>lcr::entities::product</td></tr><tr><td>lcr::services::getInflows</td></tr><tr><td>lcr::lakehouse::finos</td></tr><tr><td>lcr::entities::collateralClass</td></tr><tr><td>lcr::services::getInflowsWithBuckets</td></tr><tr><td>lcr::lakehouse::assetMapping</td></tr><tr><td>lcr::entities::currency</td></tr><tr><td>lcr::entities::asset</td></tr><tr><td>lcr::lakehouse::store</td></tr><tr><td>lcr::lakehouse::databricks</td></tr><tr><td>lcr::functions::computeMaturityBucket</td></tr></tbody></table></div>

# %%
# %scala
display(legend.getSchema("lcr::entities::asset").fields.toList.map(_.toJson).toDF("legendField"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>legendField</th></tr></thead><tbody><tr><td>{"name":"id","type":"integer","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"currency","type":"string","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"converted","type":"boolean","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"reportingEntity","type":"string","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"product","type":"string","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"subProduct","type":"string","nullable":true,"metadata":{}}</td></tr><tr><td>{"name":"marketValue","type":"long","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"lendableValue","type":"long","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"purchaseDate","type":"date","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"maturityDate","type":"date","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"forwardStartAmount","type":"long","nullable":true,"metadata":{}}</td></tr><tr><td>{"name":"forwardStartBucket","type":"integer","nullable":true,"metadata":{}}</td></tr><tr><td>{"name":"collateralClass","type":"string","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"treasuryControl","type":"boolean","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"accountingDesignation","type":"string","nullable":true,"metadata":{}}</td></tr><tr><td>{"name":"effectiveMaturityDate","type":"date","nullable":false,"metadata":{}}</td></tr><tr><td>{"name":"encumbranceType","type":"string","nullable":true,"metadata":{}}</td></tr><tr><td>{"name":"internalCounterparty","type":"string","nullable":true,"metadata":{}}</td></tr><tr><td>{"name":"businessLine","type":"string","nullable":false,"metadata":{}}</td></tr></tbody></table></div>

# %% [markdown]
# Accessing the underlying generated SQL code from pure to databricks SQL...

# %%
# %scala
println(legend.generateSql("lcr::services::getInflows"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">select `root`.product as `product`, `root`.sub_product as `subProduct`, `root`.collateral_class as `collateralClass`, `root`.market_value as `marketValue`, `assets_maturity_0`.maturity_date as `maturityDate`, `root`.encumbrance_type as `encumbranceType`, `root`.forward_start_amount as `forwardStartAmount`, `root`.forward_start_bucket as `forwardStartBucket`, `root`.treasury_control as `treasuryControl` from inflows.assets as `root` left outer join inflows.assets_maturity as `assets_maturity_0` on (`root`.id = `assets_maturity_0`.id)
# </div>

# %% [markdown]
# ... Or executing query directly resulting in a dataframe with both its technical and business constraints enforced (such as multiplicity constraints or enumerations)

# %%
# %scala
val assetMapping = legend.query("lcr::services::getInflows")
display(assetMapping.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>subProduct</th><th>collateralClass</th><th>marketValue</th><th>maturityDate</th><th>encumbranceType</th><th>forwardStartAmount</th><th>forwardStartBucket</th><th>treasuryControl</th></tr></thead><tbody><tr><td>UnencumberedAssets</td><td>Currency and Coin</td><td>a_0_Q</td><td>1444320.0</td><td>2022-12-01</td><td>encumbrance_1</td><td>null</td><td>null</td><td>true</td></tr><tr><td>Capacity</td><td>Level 1</td><td>a_1_Q</td><td>3194640.0</td><td>2022-12-06</td><td>encumbrance_2</td><td>2970648.0</td><td>2</td><td>true</td></tr><tr><td>UnrestrictedReserveBalances</td><td>Level 2a</td><td>a_2_Q</td><td>2460240.0</td><td>2023-01-03</td><td>encumbrance_3</td><td>null</td><td>null</td><td>false</td></tr><tr><td>RestrictedReserveBalances</td><td>Level 2b</td><td>a_3_Q</td><td>3733200.0</td><td>2023-01-03</td><td>encumbrance_4</td><td>null</td><td>null</td><td>true</td></tr><tr><td>UnsettledAssetPurchases</td><td>Non-HQLA</td><td>a_4_Q</td><td>3769920.0</td><td>2022-12-28</td><td>null</td><td>3350088.0</td><td>5</td><td>true</td></tr><tr><td>ForwardAssetPurchases</td><td>No Collateral Pledged</td><td>a_5_Q</td><td>1358640.0</td><td>2022-12-26</td><td>encumbrance_2</td><td>946152.0</td><td>6</td><td>false</td></tr><tr><td>EncumberedAssets</td><td>Rehypothecateable Collateral Unencumbered</td><td>s_1_Q</td><td>477360.0</td><td>2023-01-04</td><td>encumbrance_3</td><td>140760.0</td><td>7</td><td>true</td></tr><tr><td>UnencumberedAssets</td><td>Unsettled (Regular Way)</td><td>s_2_Q</td><td>3206880.0</td><td>2022-12-01</td><td>encumbrance_4</td><td>2892312.0</td><td>8</td><td>true</td></tr><tr><td>Capacity</td><td>Unsettled (Forward)</td><td>s_3_Q</td><td>3414960.0</td><td>2022-12-04</td><td>encumbrance_1</td><td>2959632.0</td><td>9</td><td>true</td></tr><tr><td>UnrestrictedReserveBalances</td><td>firm long</td><td>s_4_Q</td><td>1578960.0</td><td>2022-12-19</td><td>encumbrance_2</td><td>826200.0</td><td>10</td><td>true</td></tr></tbody></table></div>

# %% [markdown]
# ## MORPHIR
# Finally, we were able to source or data through multiple JOINs operations and necessary transformations without having to write any complex SQL code. The same can be safely passed onto **Morphir** for rule based decisioning and aggregations as set by regulators. Each of those rules have been validated and unit tested through the **Morphir** framework.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/aamend/ossf_db_ms_gs/main/images/wf_3.png' width=800/>

# %% [markdown]
# We may realize that our output dataframe may not fully comply with **Morphir** specifications (maturity date should be a bucket rather than a date). We can easily get back to legend and create a new service where all the necessary transformations are created (and unit tested) to transform raw data into **Morphir** ready data assets. By doing so, we comply with the "data contract" implied by the **Morphir** framework with no development overhead. An example is the `maturityBucket` that is derived from `transactionDate` and `maturityDate`.

# %%
# %scala
val inflows = legend.query("lcr::services::getInflowsWithBuckets")
display(inflows.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>subProduct</th><th>collateralClass</th><th>marketValue</th><th>maturityBucket</th><th>encumbranceType</th><th>forwardStartAmount</th><th>forwardStartBucket</th><th>treasuryControl</th></tr></thead><tbody><tr><td>EncumberedAssets</td><td>Currency and Coin</td><td>l_8</td><td>1884960.0</td><td>9</td><td>encumbrance_1</td><td>1241136.0</td><td>21</td><td>true</td></tr><tr><td>EncumberedAssets</td><td>Currency and Coin</td><td>l_8</td><td>1884960.0</td><td>26</td><td>encumbrance_1</td><td>1241136.0</td><td>21</td><td>true</td></tr><tr><td>UnencumberedAssets</td><td>Level 1</td><td>l_9</td><td>3268080.0</td><td>20</td><td>encumbrance_2</td><td>null</td><td>null</td><td>false</td></tr><tr><td>UnencumberedAssets</td><td>Level 1</td><td>l_9</td><td>3268080.0</td><td>2</td><td>encumbrance_2</td><td>null</td><td>null</td><td>false</td></tr><tr><td>Capacity</td><td>Level 2a</td><td>l_10</td><td>1285200.0</td><td>28</td><td>encumbrance_3</td><td>910656.0</td><td>23</td><td>true</td></tr><tr><td>Capacity</td><td>Level 2a</td><td>l_10</td><td>1285200.0</td><td>33</td><td>encumbrance_3</td><td>910656.0</td><td>23</td><td>true</td></tr><tr><td>UnrestrictedReserveBalances</td><td>Level 2b</td><td>l_11</td><td>538560.0</td><td>4</td><td>encumbrance_4</td><td>269280.0</td><td>24</td><td>true</td></tr><tr><td>UnrestrictedReserveBalances</td><td>Level 2b</td><td>l_11</td><td>538560.0</td><td>22</td><td>encumbrance_4</td><td>269280.0</td><td>24</td><td>true</td></tr><tr><td>RestrictedReserveBalances</td><td>Non-HQLA</td><td>l_12</td><td>61200.0</td><td>25</td><td>encumbrance_1</td><td>null</td><td>null</td><td>false</td></tr><tr><td>RestrictedReserveBalances</td><td>Non-HQLA</td><td>l_12</td><td>61200.0</td><td>23</td><td>encumbrance_1</td><td>null</td><td>null</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# ## MORPHIR ON SPARK

# %% [markdown]
# <img src='https://raw.githubusercontent.com/aamend/ossf_db_ms_gs/main/images/wf_4.png' width=800/>

# %%
# %scala
import regulation.us.lcr.inflows.assets.{SparkJobs => Morphir}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import regulation.us.lcr.inflows.assets.{SparkJobs=&gt;Morphir}
# </div>

# %% [markdown]
# Let's execute our first sets of LCR rules for inflows data resulting in a new dataframe

# %%
# %scala
val lcr = inflows.transform(Morphir.sumToRule)
display(lcr)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Label</th><th>value</th></tr></thead><tbody><tr><td>20(c)(1)</td><td>7.16869872E9</td></tr><tr><td>20(b)(1)</td><td>3.51023616E9</td></tr><tr><td>20(a)(1)</td><td>1.435490064E10</td></tr></tbody></table></div>

# %% [markdown]
# And safely append or overwrite its results onto a table. That table can be shared across different systems or organizations through delta sharing (see later) or mapped back onto legend to be accessed by end users.

# %%
# %scala
lcr.write.format("delta").mode("overwrite").saveAsTable("lcr.report")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## TIME TRAVEL
# Persisting our reports to Delta format, we benefit from its audit capability allowing users to travel back in time through all its previous versions.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/aamend/ossf_db_ms_gs/main/images/wf_5.png' width=800/>

# %%
# %sql
DESCRIBE HISTORY lcr.report
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>4</td><td>2022-11-30T09:36:08.000+0000</td><td>3658755248564160</td><td>antoine.amend@databricks.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(1562452343328116)</td><td>1129-000847-nuk6je0t</td><td>3</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 769)</td><td>null</td><td>Databricks-Runtime/10.4.x-photon-scala2.12</td></tr><tr><td>3</td><td>2022-11-29T20:00:04.000+0000</td><td>3658755248564160</td><td>antoine.amend@databricks.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(1562452343328116)</td><td>1129-000847-nuk6je0t</td><td>2</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 769)</td><td>null</td><td>Databricks-Runtime/10.4.x-photon-scala2.12</td></tr><tr><td>2</td><td>2022-11-29T19:57:29.000+0000</td><td>3658755248564160</td><td>antoine.amend@databricks.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(1562452343328116)</td><td>1129-000847-nuk6je0t</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 769)</td><td>null</td><td>Databricks-Runtime/10.4.x-photon-scala2.12</td></tr><tr><td>1</td><td>2022-11-29T19:57:21.000+0000</td><td>3658755248564160</td><td>antoine.amend@databricks.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(1562452343328116)</td><td>1129-000847-nuk6je0t</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 769)</td><td>null</td><td>Databricks-Runtime/10.4.x-photon-scala2.12</td></tr><tr><td>0</td><td>2022-11-29T19:56:53.000+0000</td><td>3658755248564160</td><td>antoine.amend@databricks.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(1562452343328116)</td><td>1129-000847-nuk6je0t</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 769)</td><td>null</td><td>Databricks-Runtime/10.4.x-photon-scala2.12</td></tr></tbody></table></div>

# %% [markdown]
# We access our reports as it was generated at a given point in time (regardless of susequent updates) or at a given version. This ensures audit and compliance requirements whilst guaranteeing strict reproducibility of our output since both our **Legend** and **Morphir** models are version / controlled

# %%
# %sql
SELECT * FROM lcr.report
VERSION AS OF 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Label</th><th>value</th></tr></thead><tbody><tr><td>20(c)(1)</td><td>1.83790944E9</td></tr><tr><td>20(b)(1)</td><td>8.6119416E8</td></tr><tr><td>20(a)(1)</td><td>3.68918496E9</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM lcr.report
TIMESTAMP AS OF '2022-11-29T19:57:29.000+0000'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Label</th><th>value</th></tr></thead><tbody><tr><td>20(c)(1)</td><td>1.83790944E9</td></tr><tr><td>20(b)(1)</td><td>8.6119416E8</td></tr><tr><td>20(a)(1)</td><td>3.68918496E9</td></tr></tbody></table></div>
